# %%
# Import required libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
# Load dataset
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/DSData/master/Telecom_customer_churn.csv')

# %%
print(" Data has\n Rows = ",df.shape[0],'\n Columns = ',df.shape[1])
# Out:
#  Data has
#  Rows =  7043
#  Columns =  21

# %%
# Some special char are presents in the dataset, convert them into NaN
df = df.replace(r'^\s*$', np.nan, regex=True)

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
pd.set_option('display.max_columns',None)

# %%
# Top 5 rows

df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
# last 5 records
df.tail()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  \
# 7038          Yes               Yes             DSL            Yes
# 7039          Yes               Yes     Fiber optic             No
# 7040           No  No phone service             DSL            Yes
# 7041          Yes               Yes     Fiber optic             No
# 7042          Yes                No     Fiber optic            Yes
#
#      OnlineBackup DeviceProtection TechSupport StreamingTV StreamingMovies  \
# 7038           No              Yes         Yes         Yes             Yes
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.describe().T
# Out:
#                  count       mean        std    min   25%    50%    75%  \
# SeniorCitizen   7043.0   0.162147   0.368612   0.00   0.0   0.00   0.00
# tenure          7043.0  32.371149  24.559481   0.00   9.0  29.00  55.00
# MonthlyCharges  7043.0  64.761692  30.090047  18.25  35.5  70.35  89.85
#
#                    max
# SeniorCitizen     1.00
# tenure           72.00
# MonthlyCharges  118.75

# %%
# Senior citizen is categorical features, whether customer is senior or not
# Tenure is also discrete feature.

# %% [markdown]
# **Missing Values**

# %%
df.isnull().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
#  % of missing values

(df.isnull().sum()/df.shape[0])*100
# Out:
# customerID          0.000000
# gender              0.000000
# SeniorCitizen       0.000000
# Partner             0.000000
# Dependents          0.000000
# tenure              0.000000
# PhoneService        0.000000
# MultipleLines       0.000000
# InternetService     0.000000
# OnlineSecurity      0.000000
# OnlineBackup        0.000000
# DeviceProtection    0.000000
# TechSupport         0.000000
# StreamingTV         0.000000
# StreamingMovies     0.000000
# Contract            0.000000
# PaperlessBilling    0.000000
# PaymentMethod       0.000000
# MonthlyCharges      0.000000
# TotalCharges        0.156183
# Churn               0.000000
# dtype: float64

# %%
sns.heatmap(df.isnull())

# %% [markdown]
# **Univarient Exploratory Data Analysis**

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df['customerID'].nunique()
# Out:
# 7043

# %%
# Customer ID is unique, It will be irrelevant to predict customer churn, We can dropt this feature

# %%
df['gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
sns.countplot(df['gender'])

# %%
df['gender'].value_counts(normalize=True)*100
# Out:
# Male      50.47565
# Female    49.52435
# Name: gender, dtype: float64

# %%
df['SeniorCitizen'].unique()
# Out:
# array([0, 1])

# %%
df['SeniorCitizen'].value_counts(normalize=True)*100
# Out:
# 0    83.785319
# 1    16.214681
# Name: SeniorCitizen, dtype: float64

# %%
plt.pie((df['SeniorCitizen'].value_counts(normalize=True)*100).values,labels=['Not- Senior','Senior'],autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7fad9a622b50>,
# ...
#  [Text(-0.9603414027015803, 0.5364181114179138, 'Not- Senior'),
#   Text(0.9603414278131233, -0.5364180664610878, 'Senior')],
#  [Text(-0.523822583291771, 0.29259169713704386, '83.79%'),
#   Text(0.5238225969889763, -0.29259167261513874, '16.21%')])

# %%
df['Partner'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
sns.set(style="ticks")
sns.countplot(df['Partner'])
plt.grid()

# %%
df['Partner'].value_counts(normalize=True)*100
# Out:
# No     51.69672
# Yes    48.30328
# Name: Partner, dtype: float64

# %%
df['Dependents'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
sns.countplot(df['Dependents'])
plt.grid()

# %%
df['Dependents'].value_counts(normalize=True)*100
# Out:
# No     70.041176
# Yes    29.958824
# Name: Dependents, dtype: float64

# %% [markdown]
# **tenure**

# %%
df['tenure'].unique()
# Out:
# array([ 1, 34,  2, 45,  8, 22, 10, 28, 62, 13, 16, 58, 49, 25, 69, 52, 71,
#        21, 12, 30, 47, 72, 17, 27,  5, 46, 11, 70, 63, 43, 15, 60, 18, 66,
#         9,  3, 31, 50, 64, 56,  7, 42, 35, 48, 29, 65, 38, 68, 32, 55, 37,
#        36, 41,  6,  4, 33, 67, 23, 57, 61, 14, 20, 53, 40, 59, 24, 44, 19,
#        54, 51, 26,  0, 39])

# %%
df['tenure'].nunique()
# Out:
# 73

# %%
df['tenure'].value_counts()
# Out:
# 1     613
# 72    362
# 2     238
# 3     200
# 4     176
#      ...
# 28     57
# 39     56
# 44     51
# 36     50
# 0      11
# Name: tenure, Length: 73, dtype: int64

# %%
sns.distplot(df['tenure'])

# %% [markdown]
# **PhoneService**

# %%
df['PhoneService'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
sns.countplot(df['PhoneService'])
plt.grid()

# %%
plt.pie(df['PhoneService'].value_counts().values,labels=['Phone Service Used','Not used'],autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7fad9a3a56d0>,
# ...
#  [Text(-1.0494915966975706, 0.3294956577273572, 'Phone Service Used'),
#   Text(1.049491627547176, -0.32949555946686127, 'Not used')],
#  [Text(-0.5724499618350385, 0.17972490421492213, '90.32%'),
#   Text(0.5724499786620959, -0.17972485061828794, '9.68%')])

# %% [markdown]
# **MultipleLines**

# %%
df['MultipleLines'].unique()
# Out:
# array(['No phone service', 'No', 'Yes'], dtype=object)

# %%
df['MultipleLines'].value_counts(normalize=True)*100
# Out:
# No                  48.132898
# Yes                 42.183729
# No phone service     9.683374
# Name: MultipleLines, dtype: float64

# %% [markdown]
# **MultipleLines have the information about Phone Service
# InternetService**

# %%
df['InternetService'].unique()
# Out:
# array(['DSL', 'Fiber optic', 'No'], dtype=object)

# %%
plt.pie(df['InternetService'].value_counts().values,labels=df['InternetService'].value_counts().index,autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7fad9a37d310>,
# ...
#  [Text(0.20752658810331015, 1.0802465992680557, 'Fiber optic'),
#   Text(-0.8411049099748845, -0.7089023419457307, 'DSL'),
#   Text(0.8548554654106661, -0.6922587184409551, 'No')],
#  [Text(0.11319632078362371, 0.5892254177825758, '43.96%'),
#   Text(-0.4587844963499369, -0.38667400469767127, '34.37%'),
#   Text(0.46628479931490874, -0.37759566460415733, '21.67%')])

# %%
sns.countplot(df['InternetService'],hue=df['MultipleLines'])

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %% [markdown]
# **Some extra services like**

# %%
df['OnlineSecurity'].unique()
# Out:
# array(['No', 'Yes', 'No internet service'], dtype=object)

# %%
plt.pie(df['OnlineSecurity'].value_counts().values,labels=df['OnlineSecurity'].value_counts().index,autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7fad9a2d7990>,
# ...
#  [Text(0.011530382742536482, 1.0999395666461913, 'No'),
#   Text(-0.7011814628356199, -0.8475520964375585, 'Yes'),
#   Text(0.8548554654106661, -0.6922587184409551, 'No internet service')],
#  [Text(0.006289299677747172, 0.5999670363524678, '49.67%'),
#   Text(-0.38246261609215626, -0.46230114351139545, '28.67%'),
#   Text(0.46628479931490874, -0.37759566460415733, '21.67%')])

# %% [markdown]
# **OnlineBackup**

# %%
df['OnlineBackup'].unique()
# Out:
# array(['Yes', 'No', 'No internet service'], dtype=object)

# %%
plt.pie(df['OnlineBackup'].value_counts().values,labels=df['OnlineBackup'].value_counts().index,autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7fad9a22f390>,
# ...
#  [Text(0.21138010801255863, 1.0794991662509976, 'No'),
#   Text(-0.8436292603186925, -0.7058963600516268, 'Yes'),
#   Text(0.8548554654106661, -0.6922587184409551, 'No internet service')],
#  [Text(0.11529824073412287, 0.5888177270459987, '43.84%'),
#   Text(-0.46016141471928673, -0.38503437820997827, '34.49%'),
#   Text(0.46628479931490874, -0.37759566460415733, '21.67%')])

# %% [markdown]
# **DeviceProtection**

# %%
df['DeviceProtection'].unique()
# Out:
# array(['No', 'Yes', 'No internet service'], dtype=object)

# %%
plt.pie(df['DeviceProtection'].value_counts().values,labels=df['DeviceProtection'].value_counts().index,autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7fad9a1fed50>,
# ...
#  [Text(0.20800849946792185, 1.080153907621087, 'No'),
#   Text(-0.8414211562608911, -0.708526949238055, 'Yes'),
#   Text(0.8548553357827734, -0.692258878515633, 'No internet service')],
#  [Text(0.11345918152795736, 0.589174858702411, '43.94%'),
#   Text(-0.45895699432412235, -0.38646924503893904, '34.39%'),
#   Text(0.46628472860878545, -0.3775957519176179, '21.67%')])

# %%
df['TechSupport'].unique()
# Out:
# array(['No', 'Yes', 'No internet service'], dtype=object)

# %%
plt.pie(df['TechSupport'].value_counts().values,labels=df['TechSupport'].value_counts().index,autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7fad9d4b3990>,
# ...
#  [Text(0.023795397047164612, 1.0997425967376948, 'No'),
#   Text(-0.7105891537173198, -0.8396803288271695, 'Yes'),
#   Text(0.8548554654106661, -0.6922587184409551, 'No internet service')],
#  [Text(0.012979307480271604, 0.5998595982205608, '49.31%'),
#   Text(-0.38759408384581073, -0.45800745208754695, '29.02%'),
#   Text(0.46628479931490874, -0.37759566460415733, '21.67%')])

# %% [markdown]
# **StreamingTV**

# %%
df['StreamingTV'].unique()
# Out:
# array(['No', 'Yes', 'No internet service'], dtype=object)

# %%
plt.pie(df['StreamingTV'].value_counts().values,labels=df['StreamingTV'].value_counts().index,autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7fad9a3e3850>,
# ...
#  [Text(0.3432768520552361, 1.0450650711046885, 'No'),
#   Text(-0.9244614473012522, -0.5961300465952661, 'Yes'),
#   Text(0.8548553357827734, -0.692258878515633, 'No internet service')],
#  [Text(0.18724191930285602, 0.5700354933298301, '39.90%'),
#   Text(-0.5042516985279557, -0.3251618435974179, '38.44%'),
#   Text(0.46628472860878545, -0.3775957519176179, '21.67%')])

# %% [markdown]
# **StreamingMovies**

# %%
df['StreamingMovies'].unique()
# Out:
# array(['No', 'Yes', 'No internet service'], dtype=object)

# %%
plt.pie(df['StreamingMovies'].value_counts().values,labels=df['StreamingMovies'].value_counts().index,autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7fad9a48fe90>,
# ...
#  [Text(0.3549092210143265, 1.0411721494733732, 'No'),
#   Text(-0.9310514684948953, -0.5857842290583618, 'Yes'),
#   Text(0.8548554654106661, -0.6922587184409551, 'No internet service')],
#  [Text(0.19358684782599625, 0.5679120815309308, '39.54%'),
#   Text(-0.50784625554267, -0.31951867039547005, '38.79%'),
#   Text(0.46628479931490874, -0.37759566460415733, '21.67%')])

# %% [markdown]
# **Contract**

# %%
df['Contract'].unique()
# Out:
# array(['Month-to-month', 'One year', 'Two year'], dtype=object)

# %%
plt.pie(df['Contract'].value_counts().values,labels=df['Contract'].value_counts().index,autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7fad9ab7d950>,
# ...
#  [Text(-0.17273219343040325, 1.0863533446134006, 'Month-to-month'),
#   Text(-0.526752873107977, -0.9656766594841628, 'Two year'),
#   Text(0.8709808402501051, -0.6718574074290027, 'One year')],
#  [Text(-0.09421756005294721, 0.5925563697891275, '55.02%'),
#   Text(-0.2873197489679874, -0.5267327233549979, '24.07%'),
#   Text(0.4750804583182391, -0.36646767677945596, '20.91%')])

# %% [markdown]
# **PaperlessBilling**

# %%
df['PaperlessBilling'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
plt.pie(df['PaperlessBilling'].value_counts().values,labels=df['PaperlessBilling'].value_counts().index,autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7fad9a639f10>,
# ...
#  [Text(-0.31424730634794096, 1.0541577825226467, 'Yes'),
#   Text(0.31424730634794035, -1.0541577825226467, 'No')],
#  [Text(-0.17140762164433143, 0.5749951541032617, '59.22%'),
#   Text(0.1714076216443311, -0.5749951541032617, '40.78%')])

# %% [markdown]
# **PaymentMethod**

# %%
df['PaymentMethod'].unique()
# Out:
# array(['Electronic check', 'Mailed check', 'Bank transfer (automatic)',
#        'Credit card (automatic)'], dtype=object)

# %%
plt.pie(df['PaymentMethod'].value_counts().values,labels=df['PaymentMethod'].value_counts().index,autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7fad9a0e77d0>,
# ...
#  [Text(0.5426181731482101, 0.956851878907754, 'Electronic check'),
#   Text(-1.0466614167922357, 0.33837830692653775, 'Mailed check'),
#   Text(-0.5037781622923265, -0.9778586621784185, 'Bank transfer (automatic)'),
#   Text(0.8560892632593112, -0.690732345653604, 'Credit card (automatic)')],
#  [Text(0.2959735489899328, 0.5219192066769567, '33.58%'),
#   Text(-0.5709062273412193, 0.18456998559629328, '22.89%'),
#   Text(-0.27478808852308717, -0.5333774520973191, '21.92%'),
#   Text(0.46695777995962423, -0.3767630976292385, '21.61%')])

# %% [markdown]
# **MonthlyCharges**

# %%
df['MonthlyCharges'].unique()
# Out:
# array([29.85, 56.95, 53.85, ..., 63.1 , 44.2 , 78.7 ])

# %%
sns.distplot(df['MonthlyCharges'])

# %%
# This is not Normal Distributed Data

# %% [markdown]
# **TotalCharges**

# %%
sns.distplot(df['TotalCharges'])

# %%
# Data is right skewed, we have to check for outliers as well
# have to handel missing values as well in this feature

# %%
df['TotalCharges']=df['TotalCharges'].astype(float)

# %%
df['Churn'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
sns.countplot(df['Churn'])

# %%
df['Churn'].value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
df['Churn'].value_counts(normalize=True)*100
# Out:
# No     73.463013
# Yes    26.536987
# Name: Churn, dtype: float64

# %% [markdown]
# **BiVarient Analysis**

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
sns.countplot('gender',hue='Churn',data=df)

# %%
df.groupby('gender')['Churn'].count()
# Out:
# gender
# Female    3488
# Male      3555
# Name: Churn, dtype: int64

# %%
# Approx equal no of Male and Female have churn out.

# %%
df['SeniorCitizen'].value_counts()
# Out:
# 0    5901
# 1    1142
# Name: SeniorCitizen, dtype: int64

# %%
sns.countplot('SeniorCitizen',hue='Churn',data=df)
plt.grid()

# %%
df.groupby('SeniorCitizen')['Churn'].value_counts()
# Out:
# SeniorCitizen  Churn
# 0              No       4508
#                Yes      1393
# 1              No        666
#                Yes       476
# Name: Churn, dtype: int64

# %%
1393/5901  # 23%  not seniors have churned out
# Out:
# 0.23606168446026096

# %%
1393/5901  # 23%  not seniors have churned out
# Out:
# 0.23606168446026096

# %%
# However, Senior customers have more churned out

# %%
sns.countplot('Partner',hue='Churn',data=df)

# %%
df.groupby('Partner')['Churn'].value_counts()
# Out:
# Partner  Churn
# No       No       2441
#          Yes      1200
# Yes      No       2733
#          Yes       669
# Name: Churn, dtype: int64

# %%
# Single customers, who were not have partners have churned out more

# %%
sns.countplot('Dependents',hue='Churn',data=df)

# %%
# Customers who have dependents are churned less, whil independent customers have churned out more

# %%
sns.countplot('PhoneService',hue='Churn',data=df)

# %%
# nothing insightfull info from here, 90% customers were using Phone service while 10% were not

# %%
sns.countplot('MultipleLines',hue='Churn',data=df)

# %%
sns.countplot('InternetService',hue='Churn',data=df)

# %%
# Majority of customers who churned out were using Fibre service, they might be not happy with internet speed or got cheaper paln with another company

# %%
sns.countplot('OnlineSecurity',hue='Churn',data=df)

# %%
# Majority churned out customers were using fibre and were not using Online Security

# %%
sns.countplot('OnlineBackup',hue='Churn',data=df)

# %%
# Majority churned ut customers were not using OnlineBackup service

# %%
sns.countplot('DeviceProtection',hue='Churn',data=df)

# %%
# Majority id churned out customers were not using Device Protection

# %%
sns.countplot('TechSupport',hue='Churn',data=df)

# %%
# Majority of churned out customers were not using TechSupport

# %%
sns.countplot('StreamingTV',hue='InternetService',data=df)

# %%
# More customers were streaming Tv on Fibre

# %%
sns.countplot('StreamingTV',hue='Churn',data=df)

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
sns.countplot('StreamingMovies',hue='Churn',data=df)

# %%
sns.countplot('Contract',hue='Churn',data=df)

# %%
# Month to Month renewal customers have churned out more

# %%
sns.countplot('PaperlessBilling',hue='Churn',data=df)

# %%
# more customes with paperless billing churned out more

# %%
plt.figure(figsize=(12,8))
sns.countplot('PaymentMethod',hue='Churn',data=df)

# %%
# Electronic transfer customers have churned out more

# %%
df[['tenure','MonthlyCharges','TotalCharges']]
# Out:
#       tenure  MonthlyCharges  TotalCharges
# 0          1           29.85         29.85
# 1         34           56.95       1889.50
# 2          2           53.85        108.15
# 3         45           42.30       1840.75
# 4          2           70.70        151.65
# ...      ...             ...           ...
# 7038      24           84.80       1990.50
# 7039      72          103.20       7362.90
# 7040      11           29.60        346.45
# 7041       4           74.40        306.60
# 7042      66          105.65       6844.50
#
# [7043 rows x 3 columns]

# %%
56.95*34
# Out:
# 1936.3000000000002

# %%
53.85*2
# Out:
# 107.7

# %%
plt.figure(figsize=(12,8))
sns.scatterplot('MonthlyCharges','TotalCharges',hue='Churn',size='tenure',data=df)

# %%
df['MonthlyCharges'].max()
# Out:
# 118.75

# %%
df['MonthlyCharges'].sort_values()
# Out:
# 3719     18.25
# 1529     18.40
# 6652     18.55
# 6906     18.70
# 1156     18.70
#          ...
# 5127    118.35
# 3894    118.60
# 4804    118.60
# 2115    118.65
# 4586    118.75
# Name: MonthlyCharges, Length: 7043, dtype: float64

# %%
df.sort_values('MonthlyCharges',ascending=False).head(150)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 4586  7569-NMZYQ  Female              0     Yes        Yes      72
# 2115  8984-HPEMB  Female              0      No         No      71
# 3894  5989-AXPUC  Female              0     Yes         No      68
# 4804  5734-EJKXG  Female              0      No         No      61
# 5127  8199-ZLLSA    Male              0      No         No      67
# ...          ...     ...            ...     ...        ...     ...
# 1357  7130-YXBRO    Male              0     Yes         No      48
# 1568  3292-PBZEJ    Male              1      No         No      11
# 197   6168-YBYNP    Male              0      No         No      59
# 2204  2659-VXMWZ    Male              0     Yes        Yes      67
# 3901  2773-OVBPK    Male              0     Yes         No      67
#
#      PhoneService MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 4586          Yes           Yes     Fiber optic            Yes          Yes
# ...

# %%
df.sort_values('TotalCharges').head(20)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 1654  2967-MXRAV    Male              0     Yes        Yes       1
# 6489  9318-NKNFC    Male              0      No         No       1
# 1151  8992-CEUEN  Female              0      No         No       1
# 4939  9975-SKRNR    Male              0      No         No       1
# 583   1423-BMPBQ  Female              0     Yes        Yes       1
# 1733  1015-OWJKI    Male              0      No         No       1
# 3110  6569-KTMDU  Female              0      No         No       1
# 4348  6121-VZNQB  Female              0      No         No       1
# 5336  9441-QHEVC    Male              0      No         No       1
# 367   7302-ZHMHP  Female              0      No         No       1
# 1816  1663-MHLHE    Male              0      No         No       1
# 2989  3308-MHOOC    Male              0      No        Yes       1
# 4392  3373-YZZYM    Male              0     Yes        Yes       1
# ...

# %%
# More customers have churned out with Monthly charges were more

# %%
df.sort_values('Churn')
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 4334  3969-GYXEL  Female              0      No         No      11
# 4333  5325-UWTWJ    Male              0     Yes         No      31
# 4332  4194-FJARJ  Female              0     Yes        Yes      54
# 4331  5743-KHMNA    Male              0      No         No      71
# ...          ...     ...            ...     ...        ...     ...
# 5441  3512-IZIKN  Female              0     Yes         No      70
# 1161  5868-CZJDR    Male              0      No        Yes       1
# 1159  4086-YQSNZ  Female              1     Yes         No       3
# 1163  0135-NMXAP  Female              0      No         No      12
# 2974  1481-ZUWZA    Male              0      No         No      28
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  \
# 0              No  No phone service             DSL                   No
# ...

# %%
# We have to fill Null values in TotalCharges

# %% [markdown]
# **Missing value in TotalCharge**

# %%
df.isnull().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
df[['tenure','MonthlyCharges','TotalCharges']]
# Out:
#       tenure  MonthlyCharges  TotalCharges
# 0          1           29.85         29.85
# 1         34           56.95       1889.50
# 2          2           53.85        108.15
# 3         45           42.30       1840.75
# 4          2           70.70        151.65
# ...      ...             ...           ...
# 7038      24           84.80       1990.50
# 7039      72          103.20       7362.90
# 7040      11           29.60        346.45
# 7041       4           74.40        306.60
# 7042      66          105.65       6844.50
#
# [7043 rows x 3 columns]

# %%
105.65*66
# Out:
# 6972.900000000001

# %%
# Correlation check:
data=df[['tenure','MonthlyCharges','TotalCharges','Churn']]

from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
data['Churn']=le.fit_transform(data['Churn'])

sns.heatmap(data.corr(),annot=True)

# %%
data['diff']= data['TotalCharges']  - (data['tenure']* data['MonthlyCharges'])

# %%
data
# Out:
#       tenure  MonthlyCharges  TotalCharges  Churn    diff
# 0          1           29.85         29.85      0    0.00
# 1         34           56.95       1889.50      0  -46.80
# 2          2           53.85        108.15      1    0.45
# 3         45           42.30       1840.75      0  -62.75
# 4          2           70.70        151.65      1   10.25
# ...      ...             ...           ...    ...     ...
# 7038      24           84.80       1990.50      0  -44.70
# 7039      72          103.20       7362.90      0  -67.50
# 7040      11           29.60        346.45      0   20.85
# 7041       4           74.40        306.60      1    9.00
# 7042      66          105.65       6844.50      0 -128.40
#
# [7043 rows x 5 columns]

# %%
data[data['TotalCharges'].isnull()]
# Out:
#       tenure  MonthlyCharges  TotalCharges  Churn  diff
# 488        0           52.55           NaN      0   NaN
# 753        0           20.25           NaN      0   NaN
# 936        0           80.85           NaN      0   NaN
# 1082       0           25.75           NaN      0   NaN
# 1340       0           56.05           NaN      0   NaN
# 3331       0           19.85           NaN      0   NaN
# 3826       0           25.35           NaN      0   NaN
# 4380       0           20.00           NaN      0   NaN
# 5218       0           19.70           NaN      0   NaN
# 6670       0           73.35           NaN      0   NaN
# 6754       0           61.90           NaN      0   NaN

# %%
df['TotalCharges'].min()
# Out:
# 18.8

# %%
missing=data[data['tenure']==0]
missing
# Out:
#       tenure  MonthlyCharges  TotalCharges  Churn  diff
# 488        0           52.55           NaN      0   NaN
# 753        0           20.25           NaN      0   NaN
# 936        0           80.85           NaN      0   NaN
# 1082       0           25.75           NaN      0   NaN
# 1340       0           56.05           NaN      0   NaN
# 3331       0           19.85           NaN      0   NaN
# 3826       0           25.35           NaN      0   NaN
# 4380       0           20.00           NaN      0   NaN
# 5218       0           19.70           NaN      0   NaN
# 6670       0           73.35           NaN      0   NaN
# 6754       0           61.90           NaN      0   NaN

# %%
df['TotalCharges']=np.where(df['tenure']==0,df['TotalCharges'].fillna(df['MonthlyCharges']),df['TotalCharges'])

# %%
df['tenure'].value_counts()
# Out:
# 1     613
# 72    362
# 2     238
# 3     200
# 4     176
#      ...
# 28     57
# 39     56
# 44     51
# 36     50
# 0      11
# Name: tenure, Length: 73, dtype: int64

# %%
df['tenure'].replace(0,1,inplace=True)

# %%
df['tenure'].value_counts()
# Out:
# 1     624
# 72    362
# 2     238
# 3     200
# 4     176
#      ...
# 38     59
# 28     57
# 39     56
# 44     51
# 36     50
# Name: tenure, Length: 72, dtype: int64

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
# CustomerID is releavant for our model prediction
df.drop('customerID',axis=1,inplace=True)

# %%
df.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %% [markdown]
# **Outliers**

# %%
for i in df.columns:
    if df[i].dtypes==np.number:
        sns.boxplot(df[i])
        plt.show()

# %% [markdown]
# **Encoding**

# %%
df.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %%
X=df.drop('Churn',axis=1)
Y=df['Churn']

# %%
X.shape , Y.shape
# Out:
# ((7043, 19), (7043,))

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
Y=le.fit_transform(Y)
Y
# Out:
# array([0, 0, 1, ..., 0, 1, 0])

# %%
X.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %% [markdown]
# **Transformation**

# %%
X.skew()
# Out:
# SeniorCitizen     1.833633
# tenure            0.239730
# MonthlyCharges   -0.220524
# TotalCharges      0.963316
# dtype: float64

# %%
X['tenure']=X['tenure'].astype(float)

# %%
X['tenure'].dtypes
# Out:
# dtype('float64')

# %%
num=X[['tenure','MonthlyCharges','TotalCharges']]
num
# Out:
#       tenure  MonthlyCharges  TotalCharges
# 0        1.0           29.85         29.85
# 1       34.0           56.95       1889.50
# 2        2.0           53.85        108.15
# 3       45.0           42.30       1840.75
# 4        2.0           70.70        151.65
# ...      ...             ...           ...
# 7038    24.0           84.80       1990.50
# 7039    72.0          103.20       7362.90
# 7040    11.0           29.60        346.45
# 7041     4.0           74.40        306.60
# 7042    66.0          105.65       6844.50
#
# [7043 rows x 3 columns]

# %%
from sklearn.preprocessing import power_transform
trans=power_transform(num)
trans
# Out:
# array([[-1.64619766, -1.1585412 , -1.80520648],
#        [ 0.29737751, -0.23949171,  0.25686123],
#        [-1.49696035, -0.34266505, -1.38133786],
#        ...,
#        [-0.72548575, -1.16724064, -0.85408054],
#        [-1.26620843,  0.33431207, -0.91709707],
#        [ 1.20193472,  1.33886338,  1.48322527]])

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
num=sc.fit_transform(trans)
number=pd.DataFrame(num)
number
# Out:
#              0         1         2
# 0    -1.646198 -1.158541 -1.805206
# 1     0.297378 -0.239492  0.256861
# 2    -1.496960 -0.342665 -1.381338
# 3     0.646504 -0.731079  0.235865
# 4    -1.496960  0.213545 -1.244141
# ...        ...       ...       ...
# 7038 -0.078009  0.671510  0.299107
# 7039  1.342177  1.260981  1.565492
# 7040 -0.725486 -1.167241 -0.854081
# 7041 -1.266208  0.334312 -0.917097
# 7042  1.201935  1.338863  1.483225
#
# [7043 rows x 3 columns]

# %%
cat=df[['gender','SeniorCitizen','Partner','Dependents','PhoneService','MultipleLines','InternetService','OnlineSecurity','OnlineBackup','DeviceProtection','TechSupport','StreamingTV','StreamingMovies','Contract','PaperlessBilling','PaymentMethod']]

# %%
cat
# Out:
#       gender  SeniorCitizen Partner Dependents PhoneService     MultipleLines  \
# 0     Female              0     Yes         No           No  No phone service
# 1       Male              0      No         No          Yes                No
# 2       Male              0      No         No          Yes                No
# 3       Male              0      No         No           No  No phone service
# 4     Female              0      No         No          Yes                No
# ...      ...            ...     ...        ...          ...               ...
# 7038    Male              0     Yes        Yes          Yes               Yes
# 7039  Female              0     Yes        Yes          Yes               Yes
# 7040  Female              0     Yes        Yes           No  No phone service
# 7041    Male              1     Yes         No          Yes               Yes
# 7042    Male              0      No         No          Yes                No
#
# ...

# %%
category=pd.get_dummies(cat,drop_first=True)
category
# Out:
#       SeniorCitizen  gender_Male  Partner_Yes  Dependents_Yes  \
# 0                 0            0            1               0
# 1                 0            1            0               0
# 2                 0            1            0               0
# 3                 0            1            0               0
# 4                 0            0            0               0
# ...             ...          ...          ...             ...
# 7038              0            1            1               1
# 7039              0            0            1               1
# 7040              0            0            1               1
# 7041              1            1            1               0
# 7042              0            1            0               0
#
#       PhoneService_Yes  MultipleLines_No phone service  MultipleLines_Yes  \
# 0                    0                               1                  0
# ...

# %%
number.shape , category.shape
# Out:
# ((7043, 3), (7043, 27))

# %%
type(number)  , type(category)
# Out:
# (pandas.core.frame.DataFrame, pandas.core.frame.DataFrame)

# %%
X=pd.concat([number,category],axis=1)

# %% [markdown]
# **Balance the dataset
# SMOTE**

# %%
from imblearn.over_sampling import SMOTE
sm=SMOTE()
bal_x,bal_y=sm.fit_resample(X,Y)

# %%
bal_x.shape , bal_y.shape
# Out:
# ((10348, 30), (10348,))

# %% [markdown]
# **Machine Learning**

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,f1_score

# %%
# FInd best Random_state

maxaccu=0
maxRS=0

for i in range(0,200):
    x_train,x_test,y_train,y_test= train_test_split(X,Y,random_state=i,test_size=.20)
    LR= LogisticRegression()
    LR.fit(x_train,y_train)
    pred= LR.predict(x_test)
    acc=accuracy_score(y_test,pred)
    if acc>maxaccu:
        maxaccu=acc
        maxRS=i
print("Best accuracy is ",maxaccu,"on Random State =",maxRS)
# Out:
# Best accuracy is  0.8282469836763662 on Random State = 158

# %%
x_train,x_test,y_train,y_test= train_test_split(bal_x,bal_y,random_state=158,test_size=.30)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import RidgeClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier

# %%
LR_model= LogisticRegression()
RD_model= RidgeClassifier()
DT_model= DecisionTreeClassifier()
SV_model= SVC()
KNR_model= KNeighborsClassifier()
RFR_model= RandomForestClassifier()
XGB_model= XGBClassifier()
SGH_model= SGDClassifier()
Bag_model=BaggingClassifier()
ADA_model=AdaBoostClassifier()
GB_model= GradientBoostingClassifier()

model=[LR_model,RD_model,DT_model,SV_model,KNR_model,RFR_model,XGB_model,SGH_model,Bag_model,ADA_model,GB_model ]

# %%
for m in model:
    m.fit(x_train,y_train)
    m.score(x_train,y_train)
    pred= m.predict(x_test)
    print('Accuracy_Score of ',m, 'is', accuracy_score(y_test,pred)*100)
    print('Confusion Matrix of ',m,' is \n', confusion_matrix(y_test,pred) )
    print(classification_report(y_test,pred))
    print('*'*50)
# Out:
# Accuracy_Score of  LogisticRegression() is 80.8695652173913
# Confusion Matrix of  LogisticRegression()  is
#  [[1233  347]
#  [ 247 1278]]
#               precision    recall  f1-score   support
#
#            0       0.83      0.78      0.81      1580
#            1       0.79      0.84      0.81      1525
#
#     accuracy                           0.81      3105
#    macro avg       0.81      0.81      0.81      3105
# weighted avg       0.81      0.81      0.81      3105
#
# **************************************************
# Accuracy_Score of  RidgeClassifier() is 80.61191626409018
# Confusion Matrix of  RidgeClassifier()  is
#  [[1217  363]
#  [ 239 1286]]
#               precision    recall  f1-score   support
#
#            0       0.84      0.77      0.80      1580
#            1       0.78      0.84      0.81      1525
#
#     accuracy                           0.81      3105
#    macro avg       0.81      0.81      0.81      3105
# ...

# %% [markdown]
# **CROSS Validation**

# %%
from sklearn.model_selection import cross_val_score

# %%
for i in model:
    print('Accuracy_Score of ',i, 'is', accuracy_score(y_test,i.predict(x_test))*100)
    print("cross Validation accuracy score of ",i ," is ",cross_val_score(i,X,Y,cv=5, scoring='accuracy').mean()*100)
    print('*'*50)
# Out:
# Accuracy_Score of  LogisticRegression() is 80.8695652173913
# cross Validation accuracy score of  LogisticRegression()  is  80.76118822182077
# **************************************************
# Accuracy_Score of  RidgeClassifier() is 80.61191626409018
# cross Validation accuracy score of  RidgeClassifier()  is  80.34935721659463
# **************************************************
# Accuracy_Score of  DecisionTreeClassifier() is 76.39291465378422
# cross Validation accuracy score of  DecisionTreeClassifier()  is  73.079714820311
# **************************************************
# Accuracy_Score of  SVC() is 81.256038647343
# cross Validation accuracy score of  SVC()  is  80.34945802955029
# **************************************************
# Accuracy_Score of  KNeighborsClassifier() is 80.64412238325282
# cross Validation accuracy score of  KNeighborsClassifier()  is  77.65185455513259
# **************************************************
# ...

# %% [markdown]
# **Hypertuning GradientBoostingClasifier()**

# %%
from sklearn.model_selection import GridSearchCV

# %%
params= {"learning_rate"    : [0.01,.05,.1,.2,.3,.5 ] ,
         'n_estimators':[5,50,100,200,300,400],
         "max_depth"        : [ 3, 4, 5, 6, 8]
          }

# %%
GCV= GridSearchCV(GB_model,params,cv=5,scoring='accuracy', n_jobs=-1)
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=GradientBoostingClassifier(), n_jobs=-1,
#              param_grid={'learning_rate': [0.01, 0.05, 0.1, 0.2, 0.3, 0.5],
#                          'max_depth': [3, 4, 5, 6, 8],
#                          'n_estimators': [5, 50, 100, 200, 300, 400]},
#              scoring='accuracy')

# %%
GCV.best_params_
# Out:
# {'learning_rate': 0.2, 'max_depth': 8, 'n_estimators': 200}

# %%
pred=GCV.best_estimator_.predict(x_test)

# %%
print('Accuracy score:', round(accuracy_score(y_test,pred) * 100, 2))
print('F1 score:', round(f1_score(y_test,pred) * 100, 2))
# Out:
# Accuracy score: 84.38
# F1 score: 84.38

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,pred)
sns.heatmap(confusion_matrix(y_test,pred),annot=True, fmt='d')

# %%
from sklearn.metrics import roc_auc_score,roc_curve,plot_roc_curve

# %%
plot_roc_curve(GCV.best_estimator_,x_test,y_test)
plt.title('ROC AUC Plot')
plt.show()

# %% [markdown]
# **Saving the Model**

# %%
import joblib
joblib.dump(GCV.best_estimator_,"Customer_Churn_Analysis.pkl")
# Out:
# ['Customer_Churn_Analysis.pkl']
